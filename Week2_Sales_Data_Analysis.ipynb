# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakxz/-sales-data-analysis-python-/blob/main/Week2_Sales_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    'Order_ID': range(1001, 1051),
    'Order_Date': pd.date_range(start='2024-01-01', periods=50, freq='D'),
    'Product': np.random.choice(['Laptop', 'Mobile', 'Headphones', 'Keyboard', 'Mouse'], 50),
    'Category': np.random.choice(['Electronics', 'Accessories'], 50),
    'Quantity': np.random.randint(1, 6, 50),
    'Price': np.random.randint(500, 50000, 50)
}
df = pd.DataFrame(data)
df.head()
# Out:
#    Order_ID Order_Date     Product     Category  Quantity  Price
# 0      1001 2024-01-01       Mouse  Electronics         1  13625
# 1      1002 2024-01-02      Laptop  Electronics         1  33420
# 2      1003 2024-01-03  Headphones  Electronics         5   5177
# 3      1004 2024-01-04       Mouse  Accessories         1  36826
# 4      1005 2024-01-05  Headphones  Accessories         3  35570

# %%
df['Total_Sales'] = df['Quantity'] * df['Price']

# %%
total_revenue = df['Total_Sales'].sum()
total_revenue
# Out:
# np.int64(4751210)

# %%
total_orders = df['Order_ID'].nunique()
total_orders
# Out:
# 50

# %%
product_sales = df.groupby('Product')['Total_Sales'].sum().sort_values(ascending=False)
product_sales
# Out:
# Product
# Laptop        1568372
# Headphones    1264619
# Keyboard       945734
# Mouse          497321
# Mobile         475164
# Name: Total_Sales, dtype: int64

# %%
product_sales.plot(kind='bar', title='Product-wise Sales')
plt.show()

# %%
category_sales = df.groupby('Category')['Total_Sales'].sum()
category_sales
# Out:
# Category
# Accessories    2174755
# Electronics    2576455
# Name: Total_Sales, dtype: int64

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Month'] = df['Order_Date'].dt.month

# %%
monthly_sales = df.groupby('Month')['Total_Sales'].sum()
monthly_sales
# Out:
# Month
# 1    2780222
# 2    1970988
# Name: Total_Sales, dtype: int64

# %%
df.to_csv('week2_sales_analysis_output.csv', index=False)
